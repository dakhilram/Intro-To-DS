# %% [markdown]
# <a href="https://colab.research.google.com/github/dakhilram/Intro-To-DS/blob/main/Lecture_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $Software Packages$

# %%
import pandas as pd #for Linear Algebra
import numpy as np # for numericals
import matplotlib.pyplot as plt # for plotting
import seaborn as sns #for plotting more beautiful

# %% [markdown]
# #Data Science Lifecycle

# %% [markdown]
# 1. Starting with a question : Who are you?

# %% [markdown]
# 1. How many students in the class?
# 2. Class timmings?
# 3. Who is the Professor?
# 4. Which room we are in?
# 5. What are the majors?
# 6. What year are you in?

# %% [markdown]
# #2. Data Acquisition and Data Cleaning

# %%
majors=pd.read_csv("majors.csv")
majors.head()
# Out:
#                                         Majors Terms in Attendance
# 0                  Environ Health Sciences PhD                   G
# 1                  Molecular & Cell Biology BA                   6
# 2  Applied Mathematics BA, Computer Science BA                   8
# 3                 Electrical Eng & Comp Sci BS                   4
# 4                            Public Health MPH                   G

# %%
names=pd.read_csv("names.csv")
names.head()
# Out:
#     Name     Role
# 0    Yue  Student
# 1  Kevin  Student
# 2   Ryan  Student
# 3   JOHN  Student
# 4   Alex  Student
