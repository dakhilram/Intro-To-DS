# %% [markdown]
# <a href="https://colab.research.google.com/github/dakhilram/Intro-To-DS/blob/main/Lecture_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
s=pd.Series([-1, 10, 2])

# %%
print(s.array)
# Out:
# <PandasArray>
# [-1, 10, 2]
# Length: 3, dtype: int64

# %%
print("Array Object", s.array, sep="\n")
# Out:
# Array Object
# <PandasArray>
# [-1, 10, 2]
# Length: 3, dtype: int64

# %%
print("Index Object", s.index, sep="\n")
# Out:
# Index Object
# RangeIndex(start=0, stop=3, step=1)

# %%
s=pd.Series([-1, 10, 2],index=["a","b","c"])
s
# Out:
# a    -1
# b    10
# c     2
# dtype: int64

# %%
s.index=["First","Second","Third"]
s.index
# Out:
# Index(['First', 'Second', 'Third'], dtype='object')

# %%
s=pd.Series([-1, 10, 0, 4, 6, 7],index=["a","b","c","d","e","f"])
print(s["a"])
# Out:
# -1

# %%
print(s[["a","d"]])
# Out:
# a   -1
# d    4
# dtype: int64

# %%
print(s>0)
# Out:
# a    False
# b     True
# c    False
# d     True
# e     True
# f     True
# dtype: bool

# %%
print(s[s>0])
# Out:
# b    10
# d     4
# e     6
# f     7
# dtype: int64

# %%
election=pd.read_csv("elections.csv")
election
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# ...

# %%
df_list_1 = pd.DataFrame([1, 2, 3], columns=['Number'])
df_list_1
# Out:
#    Number
# 0       1
# 1       2
# 2       3

# %%
df_list_1["Description"] = ["one", "two", "three"]
df_list_1
# Out:
#    Number Description
# 0       1         one
# 1       2         two
# 2       3       three

# %%
df_list_2 = pd.DataFrame([[1,"one"],[2,"two"],[3,"three"]], columns=["Number", "Description"])
df_list_2
# Out:
#    Number Description
# 0       1         one
# 1       2         two
# 2       3       three

# %%
df_dict_1=pd.DataFrame({"Fruit":["Strawberry","Orange"],"Price":[5.49,3.97]})
df_dict_1
# Out:
#         Fruit  Price
# 0  Strawberry   5.49
# 1      Orange   3.97

# %%
df_dict_1 = {'Fruit': ['Strawberry', 'Orange'], 'Price': [5.49, 3.97]}
pd.DataFrame(df_dict_1)
# Out:
#         Fruit  Price
# 0  Strawberry   5.49
# 1      Orange   3.97

# %%
df_dict_2=pd.DataFrame([{'Fruit': 'Strawberry', 'Price': 5.49},{'Fruit': 'Orange', 'Price': 3.97}])
df_dict_2
# Out:
#         Fruit  Price
# 0  Strawberry   5.49
# 1      Orange   3.97

# %%
s_a = pd.Series(['a1', 'a2', 'a3'],index=["r1","r2","r3"])
s_b = pd.Series(['b1', 'b2', 'b3'],index=["r1","r2","r3"])
df_ser = pd.DataFrame({"A-Coloumn":s_a,"B-Coloumn":s_b})
df_ser
# Out:
#    A-Coloumn B-Coloumn
# r1        a1        b1
# r2        a2        b2
# r3        a3        b3

# %%
df_ser=pd.DataFrame(s_a)
df_ser
# Out:
#      0
# r1  a1
# r2  a2
# r3  a3

# %%
s_a
# Out:
# r1    a1
# r2    a2
# r3    a3
# dtype: object

# %%
ser_to_df=s_a.to_frame()
ser_to_df
# Out:
#      0
# r1  a1
# r2  a2
# r3  a3
