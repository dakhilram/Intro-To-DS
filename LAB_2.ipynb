# %% [markdown]
# <a href="https://colab.research.google.com/github/dakhilram/Intro-To-DS/blob/main/LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
fruit_info = pd.DataFrame(
    data = {'fruit': ['apple', 'orange', 'banana', 'raspberry'],
    'color': ['red', 'orange', 'yellow', 'pink'],
    'price': [1.0, 0.75, 0.35, 0.05]})
fruit_info
# Out:
#        fruit   color  price
# 0      apple     red   1.00
# 1     orange  orange   0.75
# 2     banana  yellow   0.35
# 3  raspberry    pink   0.05

# %%
fruit_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fruit   4 non-null      object
#  1   color   4 non-null      object
#  2   price   4 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 224.0+ bytes

# %% [markdown]
# # **Task 1**

# %%
# Task 1.1.

fruit_info['rank1'] = [1, 2, 3, 4]
fruit_info
# Out:
#        fruit   color  price  rank1
# 0      apple     red   1.00      1
# 1     orange  orange   0.75      2
# 2     banana  yellow   0.35      3
# 3  raspberry    pink   0.05      4

# %%
# Task 1.2.

fruit_info.loc[:, 'rank2'] = fruit_info['rank1']
fruit_info
# Out:
#        fruit   color  price  rank1  rank2
# 0      apple     red   1.00      1      1
# 1     orange  orange   0.75      2      2
# 2     banana  yellow   0.35      3      3
# 3  raspberry    pink   0.05      4      4

# %% [markdown]
# #**Task 2**

# %%
# Task 2

fruit_info=fruit_info.drop(['rank1', 'rank2'], axis=1)
fruit_info
# Out:
#        fruit   color  price
# 0      apple     red   1.00
# 1     orange  orange   0.75
# 2     banana  yellow   0.35
# 3  raspberry    pink   0.05

# %% [markdown]
# #**Task 3**

# %%
# Task 3

fruit_info_caps = fruit_info.rename(columns=lambda x:x.capitalize())
fruit_info_caps
# Out:
#        Fruit   Color  Price
# 0      apple     red   1.00
# 1     orange  orange   0.75
# 2     banana  yellow   0.35
# 3  raspberry    pink   0.05
