# %% [markdown]
# <a href="https://colab.research.google.com/github/dakhilram/Intro-To-DS/blob/main/Lecture_4%2C5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
import urllib.request
import os.path
import zipfile
data_url = "https://www.ssa.gov/oact/babynames/state/namesbystate.zip"
local_filename = "babynamesbystate.zip"
if not os.path.exists(local_filename):
  with urllib.request.urlopen(data_url) as resp, open(local_filename,'wb') as f:
    f.write(resp.read())
zf = zipfile.ZipFile(local_filename, 'r')
ca_name = 'STATE.CA.TXT'
field_names = ['State', 'Sex', 'Year', 'Name', 'Count']
with zf.open(ca_name) as fh:
  babynames = pd.read_csv(fh, header=None, names=field_names)
babynames.head()
# Out:
#   State Sex  Year      Name  Count
# 0    CA   F  1910      Mary    295
# 1    CA   F  1910     Helen    239
# 2    CA   F  1910   Dorothy    220
# 3    CA   F  1910  Margaret    163
# 4    CA   F  1910   Frances    134

# %%
babyname_first_10_names=babynames.loc[:9]
babyname_first_10_names
# Out:
#   State Sex  Year       Name  Count
# 0    CA   F  1910       Mary    295
# 1    CA   F  1910      Helen    239
# 2    CA   F  1910    Dorothy    220
# 3    CA   F  1910   Margaret    163
# 4    CA   F  1910    Frances    134
# 5    CA   F  1910       Ruth    128
# 6    CA   F  1910     Evelyn    126
# 7    CA   F  1910      Alice    118
# 8    CA   F  1910   Virginia    101
# 9    CA   F  1910  Elizabeth     93

# %%
babyname_first_10_names.iloc[::2]
# Out:
#   State Sex  Year      Name  Count
# 0    CA   F  1910      Mary    295
# 2    CA   F  1910   Dorothy    220
# 4    CA   F  1910   Frances    134
# 6    CA   F  1910    Evelyn    126
# 8    CA   F  1910  Virginia    101

# %%
female_babies = babynames[babynames['Sex'] == 'F']
logical_op=babynames["Sex"]=="F"
female_babies
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 239532    CA   F  2022    Zemira      5
# 239533    CA   F  2022     Ziggy      5
# 239534    CA   F  2022     Zimal      5
# 239535    CA   F  2022     Zosia      5
# 239536    CA   F  2022     Zulay      5
#
# [239537 rows x 5 columns]

# %%
logical_op
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 407423    False
# 407424    False
# 407425    False
# 407426    False
# 407427    False
# Name: Sex, Length: 407428, dtype: bool

# %%
babynames_before_2000 = babynames[(babynames["Sex"]=="F")& (babynames['Year'] < 2000)]
babynames_before_2000
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 149050    CA   F  1999    Zareen      5
# 149051    CA   F  1999    Zeinab      5
# 149052    CA   F  1999     Zhane      5
# 149053    CA   F  1999      Zoha      5
# 149054    CA   F  1999     Zoila      5
#
# [149055 rows x 5 columns]

# %%
babynames[babynames['Name'].isin(['Bella', 'Alex', 'Ani', 'Lisa'])]
# Out:
#        State Sex  Year   Name  Count
# 6289      CA   F  1923  Bella      5
# 7512      CA   F  1925  Bella      8
# 12368     CA   F  1932   Lisa      5
# 14741     CA   F  1936   Lisa      8
# 17084     CA   F  1939   Lisa      5
# ...      ...  ..   ...    ...    ...
# 393248    CA   M  2018   Alex    495
# 396111    CA   M  2019   Alex    438
# 398983    CA   M  2020   Alex    379
# 401788    CA   M  2021   Alex    333
# 404663    CA   M  2022   Alex    344
#
# [364 rows x 5 columns]

# %%
babynames[babynames['Name'].str.startswith('N')]
# Out:
#        State Sex  Year    Name  Count
# 76        CA   F  1910   Norma     23
# 83        CA   F  1910  Nellie     20
# 127       CA   F  1910    Nina     11
# 198       CA   F  1910    Nora      6
# 310       CA   F  1911  Nellie     23
# ...      ...  ..   ...     ...    ...
# 407319    CA   M  2022   Nilan      5
# 407320    CA   M  2022   Niles      5
# 407321    CA   M  2022   Nolen      5
# 407322    CA   M  2022  Noriel      5
# 407323    CA   M  2022  Norris      5
#
# [12229 rows x 5 columns]

# %%
Bella_count=babynames[babynames['Name'] == 'Bella']['Count']
Bella_count
# Out:
# 6289        5
# 7512        8
# 35478       5
# 54491       7
# 58454       6
# 68848       6
# 73389       5
# 93605       5
# 96402       5
# 108062      7
# 111284      8
# 114684     10
# 117998     14
# 121532     17
# 125554     13
# 128953     18
# 132170     31
# 136368     15
# 139372     28
# 142923     27
# 146257     39
# 149613     65
# 153248     97
# 156962    122
# 160714    191
# 164594    213
# 168565    310
# 172654    334
# 176845    384
# 181099    439
# 185297    700
# 189465    902
# 193572    777
# 197564    761
# 201661    809
# 205640    704
# 209665    646
# 213604    644
# 217465    721
# 221222    749
# 224920    722
# 228595    567
# 232219    498
# 235890    486
# Name: Count, dtype: int64

# %%
average_count = np.mean(Bella_count)
average_count
# Out:
# 275.45454545454544

# %%
max_bella_count = babynames[babynames['Name'] == 'Bella']['Count'].max()
max_bella_count
# Out:
# 902

# %%
babynames.describe()
# Out:
#                 Year          Count
# count  407428.000000  407428.000000
# mean     1985.733609      79.543456
# std        27.007660     293.698654
# min      1910.000000       5.000000
# 25%      1969.000000       7.000000
# 50%      1992.000000      13.000000
# 75%      2008.000000      38.000000
# max      2022.000000    8260.000000

# %%
babynames.sample()
# Out:
#        State Sex  Year    Name  Count
# 404263    CA   M  2021  Eliott      5

# %%
babynames.size
# Out:
# 2037140

# %%
babynames[babynames['Year'] == 2000].iloc[:, 2:]
# Out:
#         Year      Name  Count
# 149055  2000     Emily   2958
# 149056  2000    Ashley   2831
# 149057  2000  Samantha   2579
# 149058  2000   Jessica   2485
# 149059  2000  Jennifer   2265
# ...      ...       ...    ...
# 344952  2000     Zarek      5
# 344953  2000       Zen      5
# 344954  2000     Zenon      5
# 344955  2000    Zuriel      5
# 344956  2000      Zyon      5
#
# [6285 rows x 3 columns]

# %%
babynames[babynames['Year'] == 2000].sample(4 , replace=True).iloc[:, 2:]
# Out:
#         Year        Name  Count
# 343193  2000    Leobardo     26
# 344529  2000       Nasir      6
# 344375  2000    Antonino      6
# 150064  2000  Evangelina     29

# %%
babynames['Name'].value_counts()
# Out:
# Jean         223
# Francis      221
# Guadalupe    218
# Jessie       217
# Marion       214
#             ...
# Renesme        1
# Purity         1
# Olanna         1
# Nohea          1
# Zayvier        1
# Name: Name, Length: 20437, dtype: int64

# %%
babynames.sort_values(by=['Name'])
# Out:
#        State Sex  Year     Name  Count
# 366001    CA   M  2008    Aadan      7
# 384005    CA   M  2014    Aadan      5
# 369120    CA   M  2009    Aadan      6
# 398211    CA   M  2019  Aadarsh      6
# 370306    CA   M  2010    Aaden     62
# ...      ...  ..   ...      ...    ...
# 220691    CA   F  2017    Zyrah      6
# 197529    CA   F  2011    Zyrah      5
# 217429    CA   F  2016    Zyrah      5
# 232167    CA   F  2020    Zyrah      5
# 404544    CA   M  2021    Zyrus      5
#
# [407428 rows x 5 columns]

# %%
babynames_2021 = babynames[babynames['Year'] == 2021].sort_values('Count', ascending=False)
babynames_2021.head()
# Out:
#        State Sex  Year    Name  Count
# 401665    CA   M  2021    Noah   2613
# 401666    CA   M  2021    Liam   2477
# 232168    CA   F  2021  Olivia   2402
# 232169    CA   F  2021    Emma   2179
# 401667    CA   M  2021   Mateo   2122

# %%
babynames.sort_values(['Name'], ascending=False)
# Out:
#        State Sex  Year     Name  Count
# 404544    CA   M  2021    Zyrus      5
# 197529    CA   F  2011    Zyrah      5
# 220691    CA   F  2017    Zyrah      6
# 232167    CA   F  2020    Zyrah      5
# 217429    CA   F  2016    Zyrah      5
# ...      ...  ..   ...      ...    ...
# 362040    CA   M  2007    Aaden     20
# 398211    CA   M  2019  Aadarsh      6
# 366001    CA   M  2008    Aadan      7
# 369120    CA   M  2009    Aadan      6
# 384005    CA   M  2014    Aadan      5
#
# [407428 rows x 5 columns]

# %%
babynames.sort_values("Name",key=lambda x:x.str.len(),ascending = False).head()
# Out:
#        State Sex  Year             Name  Count
# 334166    CA   M  1996  Franciscojavier      8
# 337301    CA   M  1997  Franciscojavier      5
# 339472    CA   M  1998  Franciscojavier      6
# 321792    CA   M  1991  Ryanchristopher      7
# 327358    CA   M  1993  Johnchristopher      5

# %% [markdown]
# #Lecture_5

# %%
babynames_length=babynames["Name"].str.len()
babynames["Name_Length"]= babynames_length
babynames
# Out:
#        State Sex  Year      Name  Count  Name_Length
# 0         CA   F  1910      Mary    295            4
# 1         CA   F  1910     Helen    239            5
# 2         CA   F  1910   Dorothy    220            7
# 3         CA   F  1910  Margaret    163            8
# 4         CA   F  1910   Frances    134            7
# ...      ...  ..   ...       ...    ...          ...
# 407423    CA   M  2022   Zayvier      5            7
# 407424    CA   M  2022       Zia      5            3
# 407425    CA   M  2022      Zora      5            4
# 407426    CA   M  2022    Zuriel      5            6
# 407427    CA   M  2022      Zylo      5            4
#
# [407428 rows x 6 columns]

# %%
babynames.sort_values("Name_Length", ascending=True)
babynames
# Out:
#        State Sex  Year      Name  Count  Name_Length
# 0         CA   F  1910      Mary    295            4
# 1         CA   F  1910     Helen    239            5
# 2         CA   F  1910   Dorothy    220            7
# 3         CA   F  1910  Margaret    163            8
# 4         CA   F  1910   Frances    134            7
# ...      ...  ..   ...       ...    ...          ...
# 407423    CA   M  2022   Zayvier      5            7
# 407424    CA   M  2022       Zia      5            3
# 407425    CA   M  2022      Zora      5            4
# 407426    CA   M  2022    Zuriel      5            6
# 407427    CA   M  2022      Zylo      5            4
#
# [407428 rows x 6 columns]

# %%
babynames=babynames.drop(["Name_Length"], axis=1)
babynames
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 407423    CA   M  2022   Zayvier      5
# 407424    CA   M  2022       Zia      5
# 407425    CA   M  2022      Zora      5
# 407426    CA   M  2022    Zuriel      5
# 407427    CA   M  2022      Zylo      5
#
# [407428 rows x 5 columns]

# %%
def dr_ea_count(string):
  return string.count("dr")+string.count("ea")

babynames['dr_ea_count'] = babynames['Name'].map(dr_ea_count)
babynames=babynames.sort_values(by="dr_ea_count", ascending=False)
babynames
# Out:
#        State Sex  Year      Name  Count  dr_ea_count
# 131029    CA   F  1994  Leandrea      5            3
# 101976    CA   F  1986  Deandrea      6            3
# 308131    CA   M  1985  Deandrea      6            3
# 115957    CA   F  1990  Deandrea      5            3
# 108731    CA   F  1988  Deandrea      5            3
# ...      ...  ..   ...       ...    ...          ...
# 139084    CA   F  1997     Areli     49            0
# 139083    CA   F  1997      Xena     50            0
# 139082    CA   F  1997    Unique     50            0
# 139081    CA   F  1997    Tierra     50            0
# 407427    CA   M  2022      Zylo      5            0
#
# [407428 rows x 6 columns]

# %%
babynames=babynames.drop(["dr_ea_count"], axis=1)
babynames
# Out:
#        State Sex  Year      Name  Count
# 131029    CA   F  1994  Leandrea      5
# 101976    CA   F  1986  Deandrea      6
# 308131    CA   M  1985  Deandrea      6
# 115957    CA   F  1990  Deandrea      5
# 108731    CA   F  1988  Deandrea      5
# ...      ...  ..   ...       ...    ...
# 139084    CA   F  1997     Areli     49
# 139083    CA   F  1997      Xena     50
# 139082    CA   F  1997    Unique     50
# 139081    CA   F  1997    Tierra     50
# 407427    CA   M  2022      Zylo      5
#
# [407428 rows x 5 columns]

# %%
female_babynames = babynames[babynames['Sex'] == 'F']
female_babynames
# Out:
#        State Sex  Year      Name  Count
# 131029    CA   F  1994  Leandrea      5
# 101976    CA   F  1986  Deandrea      6
# 115957    CA   F  1990  Deandrea      5
# 108731    CA   F  1988  Deandrea      5
# 147303    CA   F  1999  Andreana     11
# ...      ...  ..   ...       ...    ...
# 139085    CA   F  1997   Azucena     49
# 139084    CA   F  1997     Areli     49
# 139083    CA   F  1997      Xena     50
# 139082    CA   F  1997    Unique     50
# 139081    CA   F  1997    Tierra     50
#
# [239537 rows x 5 columns]

# %%
fig=px.line(female_babynames[female_babynames["Name"]=="Jennifer"], x="Year", y= "Count")
fig.update_layout(font_size=18)
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.line(female_babynames[female_babynames["Name"]=="Jennifer"].sort_values(["Year","Count"]), x="Year", y= "Count")
fig.update_layout(font_size=18)
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
max_jennifer_count=max(female_babynames[female_babynames["Name"]=="Jennifer"]["Count"])
max_jennifer_count
# Out:
# 6065

# %%
recent_year = female_babynames['Year'].max()
jennifer_recent_count = female_babynames[(female_babynames['Name'] == 'Jennifer') & (female_babynames['Year'] == recent_year)]
jennifer_count_recent_year = jennifer_recent_count['Count'].values[0]
jennifer_count_recent_year

#curr_jenn=female_babynames[female_babynames["Name"]=="Jennifer"]["Count"].iloc[-1]
#curr_jenn
# Out:
# 114

# %%
def ratio_to_peak1(series):
  name_recent_count = female_babynames[(female_babynames['Name'] == series) & (female_babynames['Year'] == female_babynames["Year"].max())]
  curr = name_recent_count['Count'].values[0]
  max = female_babynames[female_babynames['Name'] == series]['Count'].max()
  return curr / max

ratio_to_peak1('Jennifer')
# Out:
# 0.018796372629843364

# %%
def ratio_to_peak(series):
  return series.iloc[-1]/max(series)

# %%
jenn_counts_ser=female_babynames[female_babynames["Name"]=="Jennifer"]["Count"]
ratio_to_peak(jenn_counts_ser)
# Out:
# 0.46446826051112944

# %%
def ratio_to_peak1(series):
  name_recent_count = female_babynames[(female_babynames['Name'] == series) & (female_babynames['Year'] == female_babynames["Year"].max())]
  curr = name_recent_count['Count'].values[0]
  max = female_babynames[female_babynames['Name'] == series]['Count'].max()
  return curr / max

ratio_to_peak1('Jessica')
# Out:
# 0.013954826643648397

# %%
female_babynames.head()
# Out:
#        State Sex  Year      Name  Count
# 131029    CA   F  1994  Leandrea      5
# 101976    CA   F  1986  Deandrea      6
# 115957    CA   F  1990  Deandrea      5
# 108731    CA   F  1988  Deandrea      5
# 147303    CA   F  1999  Andreana     11

# %%
rtp_table=female_babynames.groupby("Name").agg(ratio_to_peak)  # groupby() is for grouping all the same elements
rtp_table                                                       # agg() is for including the action to perform
# Out:
# <ipython-input-204-bd296e2f7607>:1: FutureWarning:
#
# ['State', 'Sex'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#              Year     Count
# Name
# Aadhini  1.000000  1.000000
# Aadhira  0.997527  0.600000
# Aadhya   0.993571  0.120000
# Aadya    0.994065  0.241379
# Aahana   0.994065  0.461538
# ...           ...       ...
# Zyanya   0.987141  0.333333
# Zyla     0.993076  0.250000
# Zylah    0.994065  0.428571
# Zyra     0.995549  0.312500
# Zyrah    0.995545  0.833333
#
# [13782 rows x 2 columns]
